# %% [markdown]
# DEPRESSION AND STRESS PREDICTION

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

import seaborn as sns
import matplotlib.pyplot as plt
import plotly
import plotly.graph_objects as go
import plotly.offline as pyo
from plotly.offline import iplot

from sklearn.preprocessing import StandardScaler
from sklearn import model_selection
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve

# %% [markdown]
# DATA COLLECTION AND PROCESSING

# %%
#load the csv data to a pandas dataframe
df=pd.read_excel('/content/tarp dataset.xlsx')

# %%
#printing the 10 five rows of a data frame
df.head(10)
# Out:
#              Names Little interest or pleasure in doing things?  \
# 0          barjraj                                 Several days
# 1     ramdin verma                                 Several days
# 2  sharat chandran                                 Several days
# 3  birender mandal                                 Several days
# 4             amit                                 Several days
# 5           kushal                             Nearly every day
# 6            kasid                                 Several days
# 7     shiv prakash                      More than half the days
# 8     vikram singh                                 Several days
# 9           sanjay                      More than half the days
#
#   Feeling down, depressed, or hopeless?  \
# 0                            Not at all
# 1               More than half the days
# 2               More than half the days
# 3                          Several days
# 4                          Several days
# 5                            Not at all
# 6                          Several days
# 7                      Nearly every day
# 8                            Not at all
# 9               More than half the days
#
#   Trouble falling or staying asleep, or sleeping too much?  \
# 0                                         Not at all
# 1                                       Several days
# 2                            More than half the days
# 3                                       Several days
# 4                                   Nearly every day
# 5                                         Not at all
# 6                                   Nearly every day
# 7                                   Nearly every day
# 8                                       Several days
# 9                                       Several days
#
#   Feeling tired or having little energy? Poor appetite or overeating?  \
# 0                             Not at all                   Not at all
# 1                           Several days                   Not at all
# 2                           Several days      More than half the days
# 3                           Several days                 Several days
# 4                       Nearly every day      More than half the days
# 5                             Not at all                   Not at all
# 6                       Nearly every day                 Several days
# 7                           Several days      More than half the days
# 8                           Several days                   Not at all
# 9                           Several days      More than half the days
#
#   Feeling bad about yourself - or that you are a failure or have let yourself or your family down?  \
# 0                                         Not at all
# 1                                         Not at all
# 2                                       Several days
# 3                                       Several days
# 4                                         Not at all
# 5                                         Not at all
# 6                                         Not at all
# 7                                   Nearly every day
# 8                                       Several days
# 9                                       Several days
#
#   Trouble concentrating on things, such as reading the newspaper or watching television?  \
# 0                                         Not at all
# 1                                         Not at all
# 2                                       Several days
# 3                                       Several days
# 4                                         Not at all
# 5                                         Not at all
# 6                                         Not at all
# 7                            More than half the days
# 8                                         Not at all
# 9                                         Not at all
#
#                     Moving  \
# 0               Not at all
# 1             Several days
# 2             Several days
# 3               Not at all
# 4             Several days
# 5               Not at all
# 6             Several days
# 7  More than half the days
# 8             Several days
# 9             Several days
#
#   Thoughts that you would be better off dead, or of hurting yourself in some way?  \
# 0                                         Not at all
# 1                                   Nearly every day
# 2                                       Several days
# 3                                       Several days
# 4                                         Not at all
# 5                                         Not at all
# 6                                         Not at all
# 7                                       Several days
# 8                                         Not at all
# 9                                         Not at all
#
#                      Depression
# 0            Minimal depression
# 1               Mild depression
# 2           Moderate depression
# 3               Mild depression
# 4           Moderate depression
# 5            Minimal depression
# 6           Moderate depression
# 7  Moderately severe depression
# 8               Mild depression
# 9           Moderate depression

# %%
#printing the last 10 rows of a dataset
df.tail(10)
# Out:
#                   Names Little interest or pleasure in doing things?  \
# 2463               raju                             Nearly every day
# 2464            sandeep                                 Several days
# 2465              aatif                                   Not at all
# 2466              jahid                             Nearly every day
# 2467               anil                             Nearly every day
# 2468        amit sharma                                 Several days
# 2469        ankit kumar                      More than half the days
# 2470          mho najim                             Nearly every day
# 2471  ridhakaran sharma                      More than half the days
# 2472      babulal yadav                             Nearly every day
#
#      Feeling down, depressed, or hopeless?  \
# 2463                            Not at all
# 2464                            Not at all
# 2465                          Several days
# 2466               More than half the days
# 2467                          Several days
# 2468                          Several days
# 2469                      Nearly every day
# 2470                            Not at all
# 2471               More than half the days
# 2472                          Several days
#
#      Trouble falling or staying asleep, or sleeping too much?  \
# 2463                                       Several days
# 2464                                   Nearly every day
# 2465                                         Not at all
# 2466                                   Nearly every day
# 2467                                       Several days
# 2468                                   Nearly every day
# 2469                            More than half the days
# 2470                            More than half the days
# 2471                                         Not at all
# 2472                                         Not at all
#
#      Feeling tired or having little energy? Poor appetite or overeating?  \
# 2463                           Several days                   Not at all
# 2464                           Several days                   Not at all
# 2465                             Not at all                   Not at all
# 2466                More than half the days                 Several days
# 2467                           Several days      More than half the days
# 2468                       Nearly every day                 Several days
# 2469                More than half the days             Nearly every day
# 2470                       Nearly every day                   Not at all
# 2471                             Not at all             Nearly every day
# 2472                           Several days                   Not at all
#
#      Feeling bad about yourself - or that you are a failure or have let yourself or your family down?  \
# 2463                                         Not at all
# 2464                                         Not at all
# 2465                            More than half the days
# 2466                                       Several days
# 2467                            More than half the days
# 2468                            More than half the days
# 2469                            More than half the days
# 2470                                       Several days
# 2471                                       Several days
# 2472                                       Several days
#
#      Trouble concentrating on things, such as reading the newspaper or watching television?  \
# 2463                                   Nearly every day
# 2464                                       Several days
# 2465                            More than half the days
# 2466                                   Nearly every day
# 2467                            More than half the days
# 2468                                       Several days
# 2469                                         Not at all
# 2470                                       Several days
# 2471                                   Nearly every day
# 2472                                         Not at all
#
#                        Moving  \
# 2463             Several days
# 2464             Several days
# 2465             Several days
# 2466  More than half the days
# 2467  More than half the days
# 2468         Nearly every day
# 2469         Nearly every day
# 2470         Nearly every day
# 2471         Nearly every day
# 2472             Several days
#
#      Thoughts that you would be better off dead, or of hurting yourself in some way?  \
# 2463                                       Several days
# 2464                                         Not at all
# 2465                                         Not at all
# 2466                                         Not at all
# 2467                            More than half the days
# 2468                                         Not at all
# 2469                            More than half the days
# 2470                            More than half the days
# 2471                            More than half the days
# 2472                                       Several days
#
#                         Depression
# 2463           Moderate depression
# 2464               Mild depression
# 2465               Mild depression
# 2466  Moderately severe depression
# 2467  Moderately severe depression
# 2468  Moderately severe depression
# 2469  Moderately severe depression
# 2470  Moderately severe depression
# 2471  Moderately severe depression
# 2472               Mild depression

# %%
#number of rows and cols in a dataset 
df.shape
# Out:
# (2473, 11)

# %% [markdown]
# Drop unnecessary columns

# %%
df=df.drop('Names',axis=1)

# %%
#getting some info on dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2473 entries, 0 to 2472
# Data columns (total 10 columns):
#  #   Column                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                            --------------  -----
#  0   Little interest or pleasure in doing things?                                                      2473 non-null   object
#  1   Feeling down, depressed, or hopeless?                                                             2473 non-null   object
#  2   Trouble falling or staying asleep, or sleeping too much?                                          2473 non-null   object
#  3   Feeling tired or having little energy?                                                            2473 non-null   object
#  4   Poor appetite or overeating?                                                                      2473 non-null   object
#  5   Feeling bad about yourself - or that you are a failure or have let yourself or your family down?  2473 non-null   object
#  6   Trouble concentrating on things, such as reading the newspaper or watching television?            2473 non-null   object
#  7   Moving                                                                                            2473 non-null   object
#  8   Thoughts that you would be better off dead, or of hurting yourself in some way?                   2473 non-null   object
#  9   Depression                                                                                        2473 non-null   object
# dtypes: object(10)
# memory usage: 193.3+ KB

# %%
#checking for missing values
df.isnull()
# Out:
#       Little interest or pleasure in doing things?  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ...                                            ...
# 2468                                         False
# 2469                                         False
# 2470                                         False
# 2471                                         False
# 2472                                         False
#
#       Feeling down, depressed, or hopeless?  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
# ...                                     ...
# 2468                                  False
# 2469                                  False
# 2470                                  False
# 2471                                  False
# 2472                                  False
#
#       Trouble falling or staying asleep, or sleeping too much?  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2468                                              False
# 2469                                              False
# 2470                                              False
# 2471                                              False
# 2472                                              False
#
#       Feeling tired or having little energy?  Poor appetite or overeating?  \
# 0                                      False                         False
# 1                                      False                         False
# 2                                      False                         False
# 3                                      False                         False
# 4                                      False                         False
# ...                                      ...                           ...
# 2468                                   False                         False
# 2469                                   False                         False
# 2470                                   False                         False
# 2471                                   False                         False
# 2472                                   False                         False
#
#       Feeling bad about yourself - or that you are a failure or have let yourself or your family down?  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2468                                              False
# 2469                                              False
# 2470                                              False
# 2471                                              False
# 2472                                              False
#
#       Trouble concentrating on things, such as reading the newspaper or watching television?  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2468                                              False
# 2469                                              False
# 2470                                              False
# 2471                                              False
# 2472                                              False
#
#       Moving  \
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 2468   False
# 2469   False
# 2470   False
# 2471   False
# 2472   False
#
#       Thoughts that you would be better off dead, or of hurting yourself in some way?  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2468                                              False
# 2469                                              False
# 2470                                              False
# 2471                                              False
# 2472                                              False
#
#       Depression
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 2468       False
# 2469       False
# 2470       False
# 2471       False
# 2472       False
#
# [2473 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# Little interest or pleasure in doing things?                                                        0
# Feeling down, depressed, or hopeless?                                                               0
# Trouble falling or staying asleep, or sleeping too much?                                            0
# Feeling tired or having little energy?                                                              0
# Poor appetite or overeating?                                                                        0
# Feeling bad about yourself - or that you are a failure or have let yourself or your family down?    0
# Trouble concentrating on things, such as reading the newspaper or watching television?              0
# Moving                                                                                              0
# Thoughts that you would be better off dead, or of hurting yourself in some way?                     0
# Depression                                                                                          0
# dtype: int64

# %%
#statistical measures about dataset
df.describe()
# Out:
#        Little interest or pleasure in doing things?  \
# count                                          2473
# unique                                            4
# top                                    Several days
# freq                                            677
#
#        Feeling down, depressed, or hopeless?  \
# count                                   2473
# unique                                     4
# top                             Several days
# freq                                     700
#
#        Trouble falling or staying asleep, or sleeping too much?  \
# count                                                2473
# unique                                                  4
# top                                          Several days
# freq                                                  658
#
#        Feeling tired or having little energy? Poor appetite or overeating?  \
# count                                    2473                         2473
# unique                                      4                            4
# top                                Not at all                   Not at all
# freq                                      649                          680
#
#        Feeling bad about yourself - or that you are a failure or have let yourself or your family down?  \
# count                                                2473
# unique                                                  4
# top                                          Several days
# freq                                                  636
#
#        Trouble concentrating on things, such as reading the newspaper or watching television?  \
# count                                                2473
# unique                                                  4
# top                                            Not at all
# freq                                                  697
#
#               Moving  \
# count           2473
# unique             4
# top     Several days
# freq             660
#
#        Thoughts that you would be better off dead, or of hurting yourself in some way?  \
# count                                                2473
# unique                                                  4
# top                                            Not at all
# freq                                                  697
#
#                  Depression
# count                  2473
# unique                    5
# top     Moderate depression
# freq                   1147

# %% [markdown]
# SMOTE

# %%
df["Depression"].value_counts().plot(kind='bar',
                                   title='Depression prediction')
plt.show()

# %%
#tranforming categorical data to numerical
from sklearn.preprocessing import LabelEncoder 
labelencoder= LabelEncoder() 
for column in df:
    df[column] = labelencoder.fit_transform(df[column]) 
df.head(10)
# Out:
#    Little interest or pleasure in doing things?  \
# 0                                             3
# 1                                             3
# 2                                             3
# 3                                             3
# 4                                             3
# 5                                             1
# 6                                             3
# 7                                             0
# 8                                             3
# 9                                             0
#
#    Feeling down, depressed, or hopeless?  \
# 0                                      2
# 1                                      0
# 2                                      0
# 3                                      3
# 4                                      3
# 5                                      2
# 6                                      3
# 7                                      1
# 8                                      2
# 9                                      0
#
#    Trouble falling or staying asleep, or sleeping too much?  \
# 0                                                  2
# 1                                                  3
# 2                                                  0
# 3                                                  3
# 4                                                  1
# 5                                                  2
# 6                                                  1
# 7                                                  1
# 8                                                  3
# 9                                                  3
#
#    Feeling tired or having little energy?  Poor appetite or overeating?  \
# 0                                       2                             2
# 1                                       3                             2
# 2                                       3                             0
# 3                                       3                             3
# 4                                       1                             0
# 5                                       2                             2
# 6                                       1                             3
# 7                                       3                             0
# 8                                       3                             2
# 9                                       3                             0
#
#    Feeling bad about yourself - or that you are a failure or have let yourself or your family down?  \
# 0                                                  2
# 1                                                  2
# 2                                                  3
# 3                                                  3
# 4                                                  2
# 5                                                  2
# 6                                                  2
# 7                                                  1
# 8                                                  3
# 9                                                  3
#
#    Trouble concentrating on things, such as reading the newspaper or watching television?  \
# 0                                                  2
# 1                                                  2
# 2                                                  3
# 3                                                  3
# 4                                                  2
# 5                                                  2
# 6                                                  2
# 7                                                  0
# 8                                                  2
# 9                                                  2
#
#    Moving  \
# 0       2
# 1       3
# 2       3
# 3       2
# 4       3
# 5       2
# 6       3
# 7       0
# 8       3
# 9       3
#
#    Thoughts that you would be better off dead, or of hurting yourself in some way?  \
# 0                                                  2
# 1                                                  1
# 2                                                  3
# 3                                                  3
# 4                                                  2
# 5                                                  2
# 6                                                  2
# 7                                                  3
# 8                                                  2
# 9                                                  2
#
#    Depression
# 0           1
# 1           0
# 2           2
# 3           0
# 4           2
# 5           1
# 6           2
# 7           3
# 8           0
# 9           2

# %%
from imblearn.over_sampling import SMOTE
# Separate features (X) and target (y)
X = df.drop('Depression', axis=1)
y = df['Depression']

# Initialize SMOTE with default parameters
smote = SMOTE()

# Apply SMOTE to oversample the minority class
X_resampled, y_resampled = smote.fit_resample(X, y)

# Create a new DataFrame with the resampled data
df1 = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.Series(y_resampled, name='Depression')], axis=1)

# Check the shape of the resampled dataset
print("Original dataset shape:", X.shape, y.shape)
print("Resampled dataset shape:", df1.shape)
# Out:
# Original dataset shape: (2473, 9) (2473,)
# Resampled dataset shape: (5735, 10)

# %%
df1["Depression"].value_counts().plot(kind='bar',
                                   title='Depression prediction')
plt.show()

# %%
df1.head(10)
# Out:
#    Little interest or pleasure in doing things?  \
# 0                                             3
# 1                                             3
# 2                                             3
# 3                                             3
# 4                                             3
# 5                                             1
# 6                                             3
# 7                                             0
# 8                                             3
# 9                                             0
#
#    Feeling down, depressed, or hopeless?  \
# 0                                      2
# 1                                      0
# 2                                      0
# 3                                      3
# 4                                      3
# 5                                      2
# 6                                      3
# 7                                      1
# 8                                      2
# 9                                      0
#
#    Trouble falling or staying asleep, or sleeping too much?  \
# 0                                                  2
# 1                                                  3
# 2                                                  0
# 3                                                  3
# 4                                                  1
# 5                                                  2
# 6                                                  1
# 7                                                  1
# 8                                                  3
# 9                                                  3
#
#    Feeling tired or having little energy?  Poor appetite or overeating?  \
# 0                                       2                             2
# 1                                       3                             2
# 2                                       3                             0
# 3                                       3                             3
# 4                                       1                             0
# 5                                       2                             2
# 6                                       1                             3
# 7                                       3                             0
# 8                                       3                             2
# 9                                       3                             0
#
#    Feeling bad about yourself - or that you are a failure or have let yourself or your family down?  \
# 0                                                  2
# 1                                                  2
# 2                                                  3
# 3                                                  3
# 4                                                  2
# 5                                                  2
# 6                                                  2
# 7                                                  1
# 8                                                  3
# 9                                                  3
#
#    Trouble concentrating on things, such as reading the newspaper or watching television?  \
# 0                                                  2
# 1                                                  2
# 2                                                  3
# 3                                                  3
# 4                                                  2
# 5                                                  2
# 6                                                  2
# 7                                                  0
# 8                                                  2
# 9                                                  2
#
#    Moving  \
# 0       2
# 1       3
# 2       3
# 3       2
# 4       3
# 5       2
# 6       3
# 7       0
# 8       3
# 9       3
#
#    Thoughts that you would be better off dead, or of hurting yourself in some way?  \
# 0                                                  2
# 1                                                  1
# 2                                                  3
# 3                                                  3
# 4                                                  2
# 5                                                  2
# 6                                                  2
# 7                                                  3
# 8                                                  2
# 9                                                  2
#
#    Depression
# 0           1
# 1           0
# 2           2
# 3           0
# 4           2
# 5           1
# 6           2
# 7           3
# 8           0
# 9           2

# %%
#splitting the features and target 
#as we are dropping the colums so 1 if row 0
X=df1.drop(columns='Depression',axis=1)
Y=df1['Depression']

# %%
print(X)
# Out:
#       Little interest or pleasure in doing things?  \
# 0                                                3
# 1                                                3
# 2                                                3
# 3                                                3
# 4                                                3
# ...                                            ...
# 5730                                             2
# 5731                                             2
# 5732                                             0
# 5733                                             3
# 5734                                             0
#
#       Feeling down, depressed, or hopeless?  \
# 0                                         2
# 1                                         0
# 2                                         0
# 3                                         3
# 4                                         3
# ...                                     ...
# 5730                                      3
# 5731                                      0
# 5732                                      0
# 5733                                      1
# 5734                                      1
#
#       Trouble falling or staying asleep, or sleeping too much?  \
# 0                                                     2
# 1                                                     3
# 2                                                     0
# 3                                                     3
# 4                                                     1
# ...                                                 ...
# 5730                                                  0
# 5731                                                  1
# 5732                                                  0
# 5733                                                  1
# 5734                                                  1
#
#       Feeling tired or having little energy?  Poor appetite or overeating?  \
# 0                                          2                             2
# 1                                          3                             2
# 2                                          3                             0
# 3                                          3                             3
# 4                                          1                             0
# ...                                      ...                           ...
# 5730                                       1                             0
# 5731                                       1                             1
# 5732                                       1                             0
# 5733                                       1                             0
# 5734                                       1                             0
#
#       Feeling bad about yourself - or that you are a failure or have let yourself or your family down?  \
# 0                                                     2
# 1                                                     2
# 2                                                     3
# 3                                                     3
# 4                                                     2
# ...                                                 ...
# 5730                                                  0
# 5731                                                  0
# 5732                                                  0
# 5733                                                  1
# 5734                                                  3
#
#       Trouble concentrating on things, such as reading the newspaper or watching television?  \
# 0                                                     2
# 1                                                     2
# 2                                                     3
# 3                                                     3
# 4                                                     2
# ...                                                 ...
# 5730                                                  1
# 5731                                                  1
# 5732                                                  0
# 5733                                                  0
# 5734                                                  3
#
#       Moving  \
# 0          2
# 1          3
# 2          3
# 3          2
# 4          3
# ...      ...
# 5730       0
# 5731       1
# 5732       0
# 5733       1
# 5734       1
#
#       Thoughts that you would be better off dead, or of hurting yourself in some way?
# 0                                                     2
# 1                                                     1
# 2                                                     3
# 3                                                     3
# 4                                                     2
# ...                                                 ...
# 5730                                                  1
# 5731                                                  1
# 5732                                                  0
# 5733                                                  1
# 5734                                                  1
#
# [5735 rows x 9 columns]

# %%
print(Y)
# Out:
# 0       1
# 1       0
# 2       2
# 3       0
# 4       2
#        ..
# 5730    4
# 5731    4
# 5732    4
# 5733    4
# 5734    4
# Name: Depression, Length: 5735, dtype: int64

# %%
#splitting the data into training data and testing data
from sklearn.model_selection import train_test_split
X_train, X_test , Y_train, Y_test = train_test_split(X , Y, test_size=0.20, stratify=Y,  random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (5735, 9) (4588, 9) (1147, 9)

# %% [markdown]
# MODEL TRAINING

# %% [markdown]
# Logistic Regression

# %%
model=LogisticRegression()

# %%
#training the logistic regression 
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
#accuracy score
X_Train_predection=model.predict(X_train)
training_accuracy=accuracy_score(X_Train_predection,Y_train)

# %%
print("accuracy on Training data :",training_accuracy)
# Out:
# accuracy on Training data : 0.5669136878814298

# %%
#accuracy on test data
X_Test_predection=model.predict(X_test)
testing_accuracy=accuracy_score(X_Test_predection,Y_test)

# %%
print("accuracy on testing data : ",testing_accuracy)
# Out:
# accuracy on testing data :  0.5632083696599826

# %% [markdown]
# Hybrid Model (Decision Tree and Ensemble Bagging Classifier)

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
# Create a base model
base_model = DecisionTreeClassifier()

# Create an Ensemble Bagging Classifier with 10 base models
bagging_model = BaggingClassifier(base_estimator=base_model, n_estimators=10, random_state=42)

# Train the model on your data
bagging_model.fit(X_train, Y_train)

# Make predictions on your test data
y_pred = bagging_model.predict(X_test)

# Evaluate the accuracy of the model
accuracy = accuracy_score(Y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy*100))
# Out:
# Accuracy: 90.93%
# /usr/local/lib/python3.9/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning:
#
# `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.

# %%
import pickle
# train the bagging_model
# Save the model as a pickle file
with open('bagging_model1.pickle', 'wb') as f:
    pickle.dump(bagging_model, f)
